# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"C:\Users\jmasa\OneDrive - University of Johannesburg\Thesis\ML Projects\Python\Cell Voltage\data\Cell_Voltage_Data_6Mar.xlsx"
deGroot = pd.read_excel(file_path, sheet_name= "deGroot et al (2022)")
Emam1 = pd.read_excel(file_path, sheet_name= "Emam et al (2024)fig5")
Emam2 = pd.read_excel(file_path, sheet_name= "Emam et al (2024)fig6")
Emam3 = pd.read_excel(file_path, sheet_name= "Emam et al (2024)fig8")

df = pd.concat([deGroot,Emam1,Emam2,Emam3 ], ignore_index=True)
df.head()
# Out:
#    Current_Density_Acm-2  Pressure_Bar  Temperature_oC  KOH_Concentration_wt%  \
# 0                  0.018            10              50                     28
# 1                  0.018            20              50                     28
# 2                  0.018            30              50                     28
# 3                  0.018            40              50                     28
# 4                  0.018            50              50                     28
#
#    Electrodes_Gap_mm  Cell_Voltage_V
# 0                0.0           1.497
# 1                0.0           1.509
# 2                0.0           1.506
# 3                0.0           1.516
# 4                0.0           1.518

# %%
df.tail()
# Out:
#      Current_Density_Acm-2  Pressure_Bar  Temperature_oC  \
# 485                  0.110             1              50
# 486                  0.090             1              50
# 487                  0.078             1              50
# 488                  0.066             1              50
# 489                  0.054             1              50
#
#      KOH_Concentration_wt%  Electrodes_Gap_mm  Cell_Voltage_V
# 485                     10               10.0           2.054
# 486                     10               10.0           2.019
# 487                     10               10.0           1.977
# 488                     10               10.0           1.943
# 489                     10               10.0           1.902

# %%
df.to_excel('Cell_Voltage_Combined_9Mar.xlsx', index=False)
